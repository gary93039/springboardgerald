# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

json.load((open('data/world_bank_projects.json')))
worlddf=pd.read_json('data/world_bank_projects.json')
worlddf.head()
# Out:
#                                       _id  approvalfy board_approval_month  \
# 0  {u'$oid': u'52b213b38594d8a2be17c780'}        1999             November
# 1  {u'$oid': u'52b213b38594d8a2be17c781'}        2015             November
# 2  {u'$oid': u'52b213b38594d8a2be17c782'}        2014             November
# 3  {u'$oid': u'52b213b38594d8a2be17c783'}        2014              October
# 4  {u'$oid': u'52b213b38594d8a2be17c784'}        2014              October
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
# 2  2013-11-01T00:00:00Z   MINISTRY OF FINANCE AND ECONOMIC DEVEL
# 3  2013-10-31T00:00:00Z   MIN. OF PLANNING AND INT'L COOPERATION
# 4  2013-10-31T00:00:00Z                      MINISTRY OF FINANCE
#
#             closingdate                              country_namecode  \
# ...

# %%
#the 10 countries with most projects
worlddf.countryshortname.value_counts().head(10)
# Out:
# China                 19
# Indonesia             19
# Vietnam               17
# India                 16
# Yemen, Republic of    13
# Morocco               12
# Bangladesh            12
# Nepal                 12
# Africa                11
# Mozambique            11
# Name: countryshortname, dtype: int64

# %%
#finding the top 10 major project themes
data=json.load((open('data/world_bank_projects.json')))
normalize_df= json_normalize(data,'mjtheme_namecode',['_id','countryname'])

# %%
csort_df =normalize_df.set_index(['code']).sort_index()

csort_df
# Out:
#                      name                               countryname  \
# code
# 1     Economic management  Democratic Republic of Sao Tome and Prin
# 1     Economic management              Oriental Republic of Uruguay
# 1     Economic management                      Republic of Colombia
# 1     Economic management                      Republic of Colombia
# 1     Economic management                          Kingdom of Tonga
# 1     Economic management                         Republic of Yemen
# 1     Economic management          Lao People's Democratic Republic
# 1     Economic management          Lao People's Democratic Republic
# 1     Economic management                                   Ukraine
# 1     Economic management                           Pacific Islands
# 1                                             Republic of Guatemala
# 1     Economic management                        Republic of Poland
# 1                                         Republic of Cote d'Ivoire
# ...

# %%
csort_df['name'] =csort_df.name.replace('',method ='ffill')

csort_df=csort_df.reset_index()     
csort_df['_id'] = csort_df['_id'].astype(str)  
csort_df=csort_df.drop_duplicates(['_id','code'], keep='first')  

q2_df = csort_df.groupby(['code','name']).size().sort_values(ascending=False).head(10)#group df by size of code and sort by descending

q2_df
# Out:
# code  name
# 11    Environment and natural resources management    157
# 10    Rural development                               148
# 2     Public sector governance                        140
# 8     Human development                               128
# 4     Financial and private sector development        119
# 6     Social protection and risk management           116
# 7     Social dev/gender/inclusion                     114
# 5     Trade and integration                            61
# 9     Urban development                                40
# 1     Economic management                              33
# dtype: int64
